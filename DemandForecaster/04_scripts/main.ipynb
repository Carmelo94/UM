# %%
# install chromium, its driver, and selenium
# !apt -qq update
# !apt -qq install chromium-chromedriver
# !pip -qq install selenium
# !pip install -qq python-pptx

# %%
# %cd /content/drive/My Drive/Colab Notebooks/AMEX/ResponseEngineDataUpdate_v2/01_utils
# !python processdata.py
# Out:
# /content/drive/My Drive/Colab Notebooks/AMEX/ResponseEngineDataUpdate_v2/01_utils
#
# Repository: /content/drive/My Drive/Colab Notebooks/AMEX/ResponseEngineDataUpdate_v2/03_outputs/repo/20210301
#
# Exporting Data
# Done!
